# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Due to problems with the code, ChatGPT was used to help with the coding

# %%
def sampl_cond_distance(X, j):
    """
    X: data 
    j: index of the resampled row
    return: jth row is replaced in a copy of X
    """
    X_double = X.copy()

    # Split the data with/ without j
    X_j_wout = np.delete(X, j, axis=1)
    X_j = X[:, j]
    
    # Fit a linear model to predict X_j from the other columns
    model = LinearRegression().fit(X_j_wout, X_j) # noch zu ner logistic regression umbauen
    
    # Predict X_j values
    predicted_X_j = model.predict(X_j_wout)
    
    # Calculate residuals (actual - predicted)
    residuals = X_j - predicted_X_j
    
    # Sample from the residuals to preserve the distribution
    sampled_residuals = np.random.choice(residuals, size=len(residuals))
    
    # Generate new X_j values by adding sampled residuals to the predicted values
    new_X_j = predicted_X_j + sampled_residuals
    
    X_double[:, j] = new_X_j
    return X_double

# %%
def cond_rand_test(X:np.array, y:np.array, s:int, j:int): # maybe adding T:Callable again
    """
    X: samples
    y: responses
    K: number of permutations
    j: feature to analyze
    return: p-value for jth predictor
    """
    # the feature importance statistic
    help_feat = LogisticRegression().fit(X,y)
    coef = help_feat.coef_[0]

    imp_og = np.ones((s,)) * coef[j]
    imp_repl = np.ones((s,))


    for k in range(s):
        Xk = sampl_cond_distance(X, j)
        model = LogisticRegression().fit(Xk, y)
        coef = model.coef_[0]
        imp_repl[k] = coef[j]


    greater = imp_repl >= imp_og 
    pj = (1 / (s+1)) * (1+np.sum(greater))
    return pj

# %%
# Setting parameters
s = 1000  # Number of simulations
n = 500  # Number of samples
p = 200  # Number of predictors
ar_coef = 0.5  # Autoregressive coefficient
num_nonzero = 20  # Number of nonzero coefficients

# %% [markdown]
# This is the implementation of CRT.

# %%
# Bernoulli with probability 0.5 determined by the logit transformation of a linear combination of X2 to X21

p_values_bl = np.zeros(s)

for i in range(s):
    np.random.seed(i)
    X = np.random.normal(size=(n, p))
    for j in range(1, p):
        X[:, j] += ar_coef * X[:, j - 1]

    nonzero_indices = np.random.choice(np.arange(1, p), size=num_nonzero, replace=False)
    # X2 +···+X21 doesn't imply the first 20 predictors rather a sequence of Xi, that's why random.choice can be used
    X_subset = X[:, nonzero_indices]
    logit_prob = 0.08 * np.sum(X_subset, axis=1)
    y = np.random.binomial(1, p=1 / (1 + np.exp(-logit_prob)), size=n)

    # p-values for β1 using cond_rand_test function
    p_values_bl[i] = cond_rand_test(X, y, s, j=1)  # index 0 corresponds to the intercept
    
# Plot histogram of p-values
plt.hist(p_values_bl, bins=20, color='blue', edgecolor='red')
plt.title('20 Nonzero Coefficients, AR(1) Design')
plt.xlabel('P-Values')
plt.ylabel('counts')
plt.xticks(np.linspace(0, 1, num=5), ['0.00', '0.25', '0.50', '0.75', '1.00'])
plt.grid(True, color='white', linestyle='-', alpha=1)
plt.grid(True, which='both', axis='x', color='white', linestyle='-', alpha=1)
plt.grid(True, which='both', axis='y', color='white', linestyle='-', alpha=1)
plt.gca().set_facecolor('lightgrey')
plt.gca().set_axisbelow(True)
plt.show()

# %%
# p-value array
p_values_b = np.zeros(s)

# simulating data & fitting model for each simulation
for i in range(s):
    
    np.random.seed(i)
    # "i" as the seed (instead of fixed one) ensures that each simulation is INDEPENDENT(metrices assumption)
    X = np.random.normal(size=(n, p))
    for j in range(1, p):
        X[:, j] += ar_coef * X[:, j - 1]

    # variable Y
    y = np.random.binomial(1, p=0.5, size=n) # do not confuse the p here with the p in settings 

    # p-values for β1 using cond_rand_test function
    p_values_b[i] = cond_rand_test(X, y, s, j=1)  # index 0 corresponds to the intercept

# Peer review check
# Print p-values for examination
print("Generated p-values:", p_values_b)

# Plot histogram of p-values
plt.hist(p_values_b, bins=20, color='blue', edgecolor='red')
plt.title('20 Nonzero Coefficients, AR(1) Design')
plt.xlabel('P-Values')
plt.ylabel('counts')
plt.xticks(np.linspace(0, 1, num=5), ['0.00', '0.25', '0.50', '0.75', '1.00'])
plt.grid(True, color='white', linestyle='-', alpha=1)
plt.grid(True, which='both', axis='x', color='white', linestyle='-', alpha=1)
plt.grid(True, which='both', axis='y', color='white', linestyle='-', alpha=1)
plt.gca().set_facecolor('lightgrey')
plt.gca().set_axisbelow(True)
plt.show()

# %% [markdown]
# Simulation without the implementation of the CRT.

# %%
# Bernoulli with probability 0.5

# p-value array
p_values_b = np.zeros(s)

# simulating data & fitting model for each simulation
for i in range(s):
    
    np.random.seed(i)
    # "i" as the seed (instead of fixed one) ensures that each simulation is INDEPENDENT(metrices assumption)
    X = np.random.normal(size=(n, p))
    for j in range(1, p):
        X[:, j] += ar_coef * X[:, j - 1]

    # variable Y
    y = np.random.binomial(1, p=0.5, size=n) # do not confuse the p here with the p in settings 

    # logit model
    X_const = sm.add_constant(X)
    logit_model = sm.Logit(y, X_const)
    logit_result = logit_model.fit()

    # p-values for β1
    p_values_b[i] = logit_result.pvalues[1] # index 0 corresponds to the intercept

# %%
# Bernoulli with probability 0.5

# p-value array
p_values_b = np.zeros(s)

# simulating data & fitting model for each simulation
for i in range(s):
    
    np.random.seed(i)
    # "i" as the seed (instead of fixed one) ensures that each simulation is INDEPENDENT(metrices assumption)
    X = np.random.normal(size=(n, p))
    for j in range(1, p):
        X[:, j] += ar_coef * X[:, j - 1]

    # variable Y
    y = np.random.binomial(1, p=0.5, size=n) # do not confuse the p here with the p in settings 

    # logit model
    X_const = sm.add_constant(X)
    logit_model = sm.Logit(y, X_const)
    logit_result = logit_model.fit()

    # p-values for β1
    p_values_b[i] = logit_result.pvalues[1] # index 0 corresponds to the intercept
# Out:
# Optimization terminated successfully.
#          Current function value: 0.428342
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.435259
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.399956
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.412280
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.407079
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.417158
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.402582
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.438191
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.404460
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432426
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.445729
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.445526
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.454940
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.375537
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.422167
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.464010
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.429208
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.412435
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.405053
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.378098
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.453691
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.399320
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.426421
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.435074
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.426792
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.399626
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447252
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.396421
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.436753
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.456000
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.396305
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.419417
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.434734
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.420453
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.354382
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.435022
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.410496
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.384556
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.372425
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.415081
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.482603
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.390866
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.432714
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.449676
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.430482
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.471432
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.442153
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.434333
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.399933
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.411707
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.419692
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.419185
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.418254
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.418472
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.463840
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.450280
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.417484
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.427006
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.449159
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.403148
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447743
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.461614
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.405373
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.427888
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.408285
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.364097
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.414332
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.420504
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.391169
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.354359
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.395400
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.391093
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.438580
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.406718
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.420116
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.361933
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.436807
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.378939
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.434744
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462709
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.438187
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.414690
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.458267
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.364732
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.388513
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.452834
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.394684
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.429739
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.433376
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.452939
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.434718
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.428826
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.441693
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.431215
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.457024
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.477241
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.442422
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422553
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.432296
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.383470
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.451763
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.409168
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.449006
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422458
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.412290
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.416220
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.401453
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.425479
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.430080
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.460581
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.376802
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.377863
#          Iterations 8
# Optimization terminated successfully.
# ...
#          Current function value: 0.472934
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.414563
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.435316
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.427885
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.390014
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.435199
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.392666
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.450474
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.445334
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.375441
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.423950
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.395206
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.339344
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.462925
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.479886
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.434656
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.443661
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.429644
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.429572
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.401955
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.367650
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.362278
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.424126
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.417905
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.404582
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.410822
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.420214
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.461231
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.387022
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.422891
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.408243
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.440400
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.404916
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.410703
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.393141
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.407918
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.427041
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.375527
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.407787
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.449412
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421440
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.430128
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.407738
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.456601
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432871
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.454824
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.426768
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.414938
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.444022
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.450066
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.399485
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.418237
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.429409
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.398870
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.452720
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.435318
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.426836
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.420018
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.385859
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.381649
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.452315
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.409865
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.424994
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.413247
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.455033
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.410184
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.482687
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.420714
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.448975
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.458518
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.469404
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.418385
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446306
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.386537
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.441723
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.409598
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.460508
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.452557
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.416826
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.413819
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337375
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.435849
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.382194
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.410989
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.391154
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.398317
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.398367
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.460874
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367321
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.438011
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.430603
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462077
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.341046
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.442484
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.414103
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.432333
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.414111
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.387201
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.468066
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.406851
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.430008
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.398540
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.426596
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335164
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.439795
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.420473
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.460563
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.461495
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.410278
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.370600
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.430871
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.394737
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.424695
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.444765
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.418849
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.464797
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.365029
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.393469
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.464596
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.433319
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462338
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.391358
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.401765
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.432454
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.428090
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.382662
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.453024
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.356656
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.417559
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.437943
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421655
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.460725
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.464938
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.406779
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447833
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.461490
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.416696
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.430856
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.436110
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.404943
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.405123
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.472157
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.419384
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447937
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.426723
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.396571
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.440172
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.354217
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.438620
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.459456
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.445465
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.464152
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.370960
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.430029
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.439115
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.439278
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.376836
#          Iterations 8

# %%
plt.hist(p_values_b, bins=20, color='blue', edgecolor='red')
plt.title('Global Null, AR(1) Design')
plt.xlabel('P-Values')
plt.ylabel('counts')
plt.xticks(np.linspace(0, 1, num=5), ['0.00', '0.25', '0.50', '0.75', '1.00'])
plt.grid(True, color='white', linestyle='-', alpha=1)
plt.grid(True, which='both', axis='x', color='white', linestyle='-', alpha=1)
plt.grid(True, which='both', axis='y', color='white', linestyle='-', alpha=1)
plt.gca().set_facecolor('lightgrey')
plt.gca().set_axisbelow(True)
plt.show()

# %%
# Bernoulli with probability 0.5 determined by the logit transformation of a linear combination of X2 to X21

num_nonzero = 20

p_values_bl = np.zeros(s)

for i in range(s):
    np.random.seed(i)
    X = np.random.normal(size=(n, p))
    for j in range(1, p):
        X[:, j] += ar_coef * X[:, j - 1]

    nonzero_indices = np.random.choice(np.arange(1, p), size=num_nonzero, replace=False)
    # X2 +···+X21 doesn't imply the first 20 predictors rather a sequence of Xi, that's why random.choice can be used
    X_subset = X[:, nonzero_indices]
    logit_prob = 0.08 * np.sum(X_subset, axis=1)
    y = np.random.binomial(1, p=1 / (1 + np.exp(-logit_prob)), size=n)

    X_const = sm.add_constant(X)
    logit_model = sm.Logit(y, X_const)
    logit_result = logit_model.fit()

    p_values_bl[i] = logit_result.pvalues[1]
# Out:
# Optimization terminated successfully.
#          Current function value: 0.431177
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.358799
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.380621
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.418471
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.378761
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.354343
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447951
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.362959
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.